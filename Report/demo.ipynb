# %%
# !pip install scikit-learn
# !pip install xgboost
# !pip install statsmodels
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0
# Collecting xgboost
#   Downloading xgboost-3.1.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.1.2-py3-none-win_amd64.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/72.0 MB 8.4 MB/s eta 0:00:09
#    ------ --------------------------------- 11.8/72.0 MB 37.9 MB/s eta 0:00:02
#    --------------- ------------------------ 28.6/72.0 MB 55.4 MB/s eta 0:00:01
#    ------------------------ --------------- 44.6/72.0 MB 64.5 MB/s eta 0:00:01
#    ------------------------------- -------- 56.9/72.0 MB 65.2 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 62.3 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 62.3 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 49.1 MB/s  0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.2
# Collecting statsmodels
#   Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from statsmodels) (2.3.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from statsmodels) (2.3.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\onedrive\document\pythonproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.14.6

# %% [markdown]
# # Mục lục
# ## 1. Giới thiệu (Introduction)
#
# ### 1.1. Đặt vấn đề & Tầm quan trọng
# > *Tại sao cần dự báo điểm thi?*
#
# ### 1.2. Bối cảnh giáo dục 2025
# > *Chương trình mới, cấu trúc đề mới → Lý do xuất hiện "Điểm gãy".*
#
# ### 1.3. Mục tiêu dự án
# * Mục tiêu 1...
# * Mục tiêu 2...
#
# ---
#
# ## 2. Dữ liệu và Pipeline xử lý
#
# ### 2.1. Nguồn dữ liệu
# * **Dataset 2023:** ...
# * **Dataset 2024:** ...
# * **Dataset 2025:** ...
#
# ### 2.2. Quy trình xử lý (Pipeline)
# > Raw → Clean → Feature Eng
#
# ### 2.3. Các phương pháp & Mô hình sử dụng
# * **Change Point Detection:** CUSUM, Pettitt...
# * **Forecasting:** ARIMA, XGBoost...
# * **Stats:** ANOVA...
#
# ---
#
# ## 3. Phân tích Xu hướng & Tỉ lệ tổ hợp
# > *Phần này giải quyết vế "Tỉ lệ tổ hợp" trong tên đề tài.*
#
# ### 3.1. Xu hướng lựa chọn bài thi tổ hợp
# > So sánh tỉ lệ chọn KHTN vs KHXH qua 3 năm.
#
# ### 3.2. Sự dịch chuyển thí sinh giữa các khối thi
# > Phân tích các khối A00, A01, D01...
#
# ---
#
# ## 4. Phân tích phổ điểm & Kiểm định thống kê
#
# ### 4.1. Phổ điểm theo Môn & Khối
# > So sánh shape của biểu đồ phân phối (Distribution Plot).
#
# ### 4.2. Phân tích theo vùng miền
# > Phân tích theo Tỉnh/Thành phố trọng điểm (TP.HCM, Hà Nội...).
#
# ### 4.3. Kiểm định sự khác biệt
# > Sử dụng ANOVA/t-test để chứng minh sự khác biệt có ý nghĩa thống kê.
#
# ---
#
# ## 5. Phân tích Điểm gãy cấu trúc 2025
# > **Highlight:** Trọng tâm của bài báo cáo.
#
# ### 5.1. Phát hiện điểm gãy
# > Sử dụng thuật toán CUSUM, Pettitt hoặc Chow Test để xác định sự thay đổi đột ngột trong mean/variance.
#
# ### 5.2. Đánh giá tác động của đổi mới quy chế thi
# > Tác động cụ thể lên điểm số năm 2025 so với trend quá khứ.
#
# ---
#
# ## 6. Xây dựng mô hình Dự báo 2026
#
# ### 6.1. Thiết lập bài toán dự báo
# * **Input:** ...
# * **Output:** ...
#
# ### 6.2. Huấn luyện mô hình
# > So sánh ARIMA vs Random Forest/XGBoost.
#
# ### 6.3. Đánh giá độ chính xác
# * **RMSE:** ...
# * **MAE:** ...
#
# ### 6.4. Kết quả dự báo
# > Dự báo phổ điểm hoặc điểm chuẩn năm 2026.
#
# ---
#
# ## 7. Kết luận & Hướng phát triển
#
# ### 7.1. Tổng kết
# * Phát hiện 1...
# * Phát hiện 2...
#
# ### 7.2. Hạn chế
# > Dữ liệu lịch sử ngắn, biến động chính sách...
#
# ### 7.3. Đề xuất hướng nghiên cứu
# > Thêm biến giải thích, mô hình nâng cao...
